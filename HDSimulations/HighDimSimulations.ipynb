# %%
# %reload_ext autoreload
# %autoreload 2

import torch
import numpy as np
import modelHD as mhd

# %% [markdown]
# ### **Figure 2**

# %%
kappa = 0.7
kappastar = 0.5
Delta = 0.
lam = np.array([0.5, 0.1, 0.05])

xi = torch.stack([torch.logspace(-0.6, 3, 1000), torch.logspace(-1.5, 3, 1000), torch.logspace(-2, 3, 1000)])

Sim = mhd.Simulator(kappa, kappastar, xi, lam, Delta, False, 'Figure2')
Sim.simulate()
Sim.save()
# Out:
# [1/3] kappa=0.7, kappastar=0.5, lam=0.5, Delta=0.0
# [step 0999] xi=1000.00000000   alpha=0.00153660   q=57.82985769   MSE=3.07320325
# [2/3] kappa=0.7, kappastar=0.5, lam=0.1, Delta=0.0
# [step 0999] xi=1000.00000000   alpha=0.00153716   q=57.81040834   MSE=3.07432069
# [3/3] kappa=0.7, kappastar=0.5, lam=0.05, Delta=0.0
# [step 0999] xi=1000.00000000   alpha=0.00153723   q=57.80797446   MSE=3.07446129
# Saving Simulator...
# ID = Figure2

# %% [markdown]
# ### **Figure 3**

# %%
kappa = 1
kappastar = 0.3
lam = np.array([5.0, 2.0, 1.0, 0.5, 0.2, 0.1, 0.05, 0.01, 0.005, 0.001])
Delta = np.array([0., 0.5])

xi1 = torch.stack([torch.logspace(0.3, 3, 200), torch.logspace(-0.15, 3, 200), torch.logspace(-0.6, 3, 200), 
                   torch.logspace(-1.0, 3, 200), torch.logspace(-1.7, 3, 200), torch.logspace(-2.3, 3, 200), 
                   torch.logspace(-2.9, 3, 200), torch.logspace(-4.3, 3, 200), torch.logspace(-4.9, 3, 200), torch.logspace(-6.3, 3, 200)])
xi2 = torch.stack([torch.logspace(0.3, 3, 200), torch.logspace(-0.1, 3, 200), torch.logspace(-0.4, 3, 200), 
                   torch.logspace(-0.6, 3, 200), torch.logspace(-0.7, 3, 200), torch.logspace(-0.7, 3, 200), 
                   torch.logspace(-0.7, 3, 200), torch.logspace(-0.7, 3, 200), torch.logspace(-0.6, 3, 200), torch.logspace(-0.6, 3, 200)])

ID1 = 'Figure3A'
ID2 = 'Figure3B'

Sim = mhd.Simulator(kappa, kappastar, xi1, lam, Delta[0], False, ID1)
Sim.simulate()
Sim.save()

noisy = [False, False, False, False, False, False, False, True, True, True]

Sim = mhd.Simulator(kappa, kappastar, xi2, lam, Delta[1], noisy, ID2)
Sim.simulate()
Sim.save()
# Out:
# [1/10] kappa=1, kappastar=0.3, lam=5.0, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00222482   q=57.06329786   MSE=4.44963644
# [2/10] kappa=1, kappastar=0.3, lam=2.0, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223218   q=56.88361733   MSE=4.46436333
# [3/10] kappa=1, kappastar=0.3, lam=1.0, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223473   q=56.82444879   MSE=4.46946713
# [4/10] kappa=1, kappastar=0.3, lam=0.5, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223603   q=56.79496892   MSE=4.47205551
# [5/10] kappa=1, kappastar=0.3, lam=0.2, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223681   q=56.77734068   MSE=4.47362277
# [6/10] kappa=1, kappastar=0.3, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223707   q=56.77147728   MSE=4.47414578
# [7/10] kappa=1, kappastar=0.3, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223720   q=56.76853090   MSE=4.47440908
# [8/10] kappa=1, kappastar=0.3, lam=0.01, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223731   q=56.76617500   MSE=4.47461726
# [9/10] kappa=1, kappastar=0.3, lam=0.005, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223732   q=56.76589017   MSE=4.47464017
# [10/10] kappa=1, kappastar=0.3, lam=0.001, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223733   q=56.76565547   MSE=4.47466118
# Saving Simulator...
# ID = Figure3A
# [1/10] kappa=1, kappastar=0.3, lam=5.0, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00235694   q=56.88918723   MSE=4.46388946
# [2/10] kappa=1, kappastar=0.3, lam=2.0, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00236513   q=56.70402499   MSE=4.48025520
# [3/10] kappa=1, kappastar=0.3, lam=1.0, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00236796   q=56.64302866   MSE=4.48592837
# [4/10] kappa=1, kappastar=0.3, lam=0.5, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00236940   q=56.61265909   MSE=4.48880624
# [5/10] kappa=1, kappastar=0.3, lam=0.2, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00237027   q=56.59446449   MSE=4.49054748
# [6/10] kappa=1, kappastar=0.3, lam=0.1, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00237056   q=56.58840988   MSE=4.49112977
# [7/10] kappa=1, kappastar=0.3, lam=0.05, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00237071   q=56.58538380   MSE=4.49142133
# [8/10] kappa=1, kappastar=0.3, lam=0.01, Delta=0.5
# [step 0073] xi=7.74627919   alpha=0.14931544   q=2.44385698   MSE=2.06327820
# [step 0060] xi=1000.00009593   alpha=0.00237083   q=56.58296632   MSE=4.49165202
# [9/10] kappa=1, kappastar=0.3, lam=0.005, Delta=0.5
# [step 0084] xi=7.68937127   alpha=0.14993395   q=2.42245564   MSE=2.05579555
# [step 0060] xi=1000.00009593   alpha=0.00237084   q=56.58266382   MSE=4.49168121
# [10/10] kappa=1, kappastar=0.3, lam=0.001, Delta=0.5
# [step 0111] xi=7.92794974   alpha=0.14765613   q=2.48022186   MSE=2.09122082
# [step 0060] xi=1000.00009593   alpha=0.00237085   q=56.58242182   MSE=4.49170457
# Saving Simulator...
# ID = Figure3B

# %% [markdown]
# ### **Figure 4**

# %%
kappa = 0.35
kappastar = 0.3
lam = np.array([0.1, 0.05, 0.01])
Delta = 0.

xi = torch.stack([torch.logspace(-2.2, 3, 1000), torch.logspace(-2.8, 3, 1000), torch.logspace(-4.2, 3, 1000)])

Sim = mhd.Simulator(kappa, kappastar, xi, lam, Delta, False, 'Figure4')
Sim.simulate()
Sim.save()
# Out:
# [1/3] kappa=0.35, kappastar=0.3, lam=0.1, Delta=0.0
# [step 0999] xi=1000.00000000   alpha=0.00223707   q=56.77146240   MSE=4.47414195
# [2/3] kappa=0.35, kappastar=0.3, lam=0.05, Delta=0.0
# [step 0999] xi=1000.00000000   alpha=0.00223720   q=56.76852385   MSE=4.47440455
# [3/3] kappa=0.35, kappastar=0.3, lam=0.01, Delta=0.0
# [step 0999] xi=1000.00000000   alpha=0.00223731   q=56.76617963   MSE=4.47461426
# Saving Simulator...
# ID = Figure4

# %% [markdown]
# ### **Figure 6**

# %%
kappa = 0.4
kappastar = 0.3

lam1 = 0.01
delta1 = [0.1, 0.25, 0.5, 1.0]
lam2 = [0.1, 0.05, 0.01, 0.005, 0.001, 0.0002]
delta2 = 1.0

xi1 = torch.stack([torch.logspace(-1.2, 3, 200), torch.logspace(-0.8, 3, 200), 
                   torch.logspace(-0.5, 3, 200), torch.logspace(-0.2, 3, 200)])

xi2 = torch.stack([torch.logspace(-0.3, 3, 200), torch.logspace(-0.2, 3, 200), 
                   torch.logspace(-0.2, 3, 200), torch.logspace(-0.2, 3, 200), 
                   torch.logspace(-0.2, 3, 200), torch.logspace(-0.2, 3, 200)])


Sim = mhd.Simulator(kappa, kappastar, xi1, lam1, delta1, True, 'Figure6A')
Sim.simulate()
Sim.save()

noisy = [False, False, True, True, True, True]

Sim = mhd.Simulator(kappa, kappastar, xi2, lam2, delta2, noisy, 'Figure6B')
Sim.simulate()
Sim.save()
# Out:
# [1/4] kappa=0.4, kappastar=0.3, lam=0.01, Delta=0.1
# [step 0063] xi=6.24653071   alpha=0.14844929   q=2.31151533   MSE=1.80458609
# [step 0060] xi=1000.00009593   alpha=0.00226398   q=56.72909018   MSE=4.47796259
# [2/4] kappa=0.4, kappastar=0.3, lam=0.01, Delta=0.25
# [step 0065] xi=6.95771293   alpha=0.14741518   q=2.40121174   MSE=1.92634496
# [step 0060] xi=1000.00009593   alpha=0.00230402   q=56.67387575   MSE=4.48303916
# [3/4] kappa=0.4, kappastar=0.3, lam=0.01, Delta=0.5
# [step 0081] xi=7.76034102   alpha=0.14917761   q=2.44755765   MSE=2.06533830
# [step 0060] xi=1000.00009593   alpha=0.00237083   q=56.58296632   MSE=4.49165202
# [4/4] kappa=0.4, kappastar=0.3, lam=0.01, Delta=1.0
# [step 0079] xi=9.88645598   alpha=0.14714807   q=2.66857342   MSE=2.40954593
# [step 0060] xi=1000.00009593   alpha=0.00250472   q=56.40511226   MSE=4.50944062
# Saving Simulator...
# ID = Figure6A
# [1/6] kappa=0.4, kappastar=0.3, lam=0.1, Delta=1.0
# [step 0199] xi=1000.00000000   alpha=0.00250443   q=56.41072639   MSE=4.50885944
# [2/6] kappa=0.4, kappastar=0.3, lam=0.05, Delta=1.0
# [step 0199] xi=1000.00000000   alpha=0.00250459   q=56.40761509   MSE=4.50918120
# [3/6] kappa=0.4, kappastar=0.3, lam=0.01, Delta=1.0
# [step 0079] xi=9.88645598   alpha=0.14714807   q=2.66857342   MSE=2.40954593
# [step 0060] xi=1000.00009593   alpha=0.00250472   q=56.40511226   MSE=4.50944062
# [4/6] kappa=0.4, kappastar=0.3, lam=0.005, Delta=1.0
# [step 0080] xi=9.74213525   alpha=0.14859453   q=2.62385124   MSE=2.39525611
# [step 0060] xi=1000.00009593   alpha=0.00250474   q=56.40480079   MSE=4.50947289
# [5/6] kappa=0.4, kappastar=0.3, lam=0.001, Delta=1.0
# [step 0111] xi=9.91309316   alpha=0.14709095   q=2.66227863   MSE=2.416252523
# [step 0060] xi=1000.00009593   alpha=0.00250475   q=56.40455163   MSE=4.50949870
# [6/6] kappa=0.4, kappastar=0.3, lam=0.0002, Delta=1.0
# [step 0108] xi=9.63734768   alpha=0.14969996   q=2.58914013   MSE=2.385421117
# [step 0060] xi=1000.00009593   alpha=0.00250475   q=56.40450180   MSE=4.50950386
# Saving Simulator...
# ID = Figure6B

# %% [markdown]
# ### **Figure 7**

# %%
kappa = 0.3
kappastar = 0.2
lam = [0.1, 0.05, 0.01, 0.005, 0.]
delta = 0.

xi = torch.stack([torch.logspace(-1.9, 3, 200), torch.logspace(-2.5, 3, 200), 
                  torch.logspace(-3.8, 3, 200), torch.logspace(-4.5, 3, 200), 
                  torch.logspace(-5.5, 3, 200)])


Sim = mhd.Simulator(kappa, kappastar, xi, lam, delta, False, 'Figure7')
Sim.simulate()
Sim.save()
# Out:
# [1/5] kappa=0.3, kappastar=0.2, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00311818   q=55.71549044   MSE=6.23636064
# [2/5] kappa=0.3, kappastar=0.2, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00311840   q=55.71199834   MSE=6.23680983
# [3/5] kappa=0.3, kappastar=0.2, lam=0.01, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00311858   q=55.70920428   MSE=6.23716963
# [4/5] kappa=0.3, kappastar=0.2, lam=0.005, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00311861   q=55.70885549   MSE=6.23721457
# [5/5] kappa=0.3, kappastar=0.2, lam=0.0, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00311863   q=55.70850593   MSE=6.23725962Saving Simulator...
# ID = Figure7

# %% [markdown]
# ### **Figure 10**

# %%
kappa = 0.7
kappastar = 0.5
lam = 0.
delta = 0.5

xi = torch.logspace(-0.6, 1, 200)

Sim = mhd.Simulator(kappa, kappastar, xi, lam, delta, True, 'Figure10')
Sim.simulate()
Sim.save()
# Out:
# [1/1] kappa=0.7, kappastar=0.5, lam=0.0, Delta=0.5
# Step[200/200], xi = 10.0, alpha = 0.297, MSE = 5.685, crit = Falsee
# Saving Simulator...
# ID = Figure10

# %% [markdown]
# ### **Figure 16**

# %%
kappa = np.array([0.4, 0.35, 0.32, 0.3])
kappastar = 0.3
lam = np.array([0.1, 0.05, 0.01])
delta = 0.

xi0 = torch.stack([torch.logspace(-2.1, 3, 200), torch.logspace(-2.7, 3, 200), torch.logspace(-4.1, 3, 200)])
xi = xi0.unsqueeze(0).repeat(4, 1, 1)

Sim = mhd.Simulator(kappa, kappastar, xi, lam, delta, False, 'Figure16')
Sim.simulate()
Sim.save()
# Out:
# [1/12] kappa=0.4, kappastar=0.3, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223707   q=56.77147291   MSE=4.47414617
# [2/12] kappa=0.4, kappastar=0.3, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223720   q=56.76853021   MSE=4.47440656
# [3/12] kappa=0.4, kappastar=0.3, lam=0.01, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223731   q=56.76619744   MSE=4.47461784
# [4/12] kappa=0.35, kappastar=0.3, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223707   q=56.77147291   MSE=4.47414617
# [5/12] kappa=0.35, kappastar=0.3, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223720   q=56.76853021   MSE=4.47440656
# [6/12] kappa=0.35, kappastar=0.3, lam=0.01, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223731   q=56.76619744   MSE=4.47461784
# [7/12] kappa=0.32, kappastar=0.3, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223707   q=56.77147291   MSE=4.47414617
# [8/12] kappa=0.32, kappastar=0.3, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223720   q=56.76853021   MSE=4.47440656
# [9/12] kappa=0.32, kappastar=0.3, lam=0.01, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223731   q=56.76619744   MSE=4.47461784
# [10/12] kappa=0.3, kappastar=0.3, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223707   q=56.77147291   MSE=4.47414617
# [11/12] kappa=0.3, kappastar=0.3, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223720   q=56.76853021   MSE=4.47440656
# [12/12] kappa=0.3, kappastar=0.3, lam=0.01, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223731   q=56.76619744   MSE=4.47461784
# Saving Simulator...
# ID = Figure16

# %% [markdown]
# ### **Figure 17**

# %%
kappa = np.array([0.5, 0.5, 0.5, 0.7, 0.7, 0.7, 0.7])
kappastar = np.array([0.2, 0.3, 0.5, 0.3, 0.5, 0.6, 0.7])
lam = np.array([0.5, 0.1, 0.05])
delta = 0.

xi = torch.stack([torch.stack([torch.logspace(-1.2, 3, 200), torch.logspace(-2.5, 3, 200), torch.logspace(-3.1, 3, 200)]), 
                  torch.stack([torch.logspace(-0.9, 3, 200), torch.logspace(-2.2, 3, 200), torch.logspace(-2.7, 3, 200)]),
                  torch.stack([torch.logspace(-0.7, 3, 200), torch.logspace(-1.7, 3, 200), torch.logspace(-2.2, 3, 200)]),
                  torch.stack([torch.logspace(-0.9, 3, 200), torch.logspace(-2.1, 3, 200), torch.logspace(-2.7, 3, 200)]),
                  torch.stack([torch.logspace(-0.7, 3, 200), torch.logspace(-1.7, 3, 200), torch.logspace(-2.2, 3, 200)]),
                  torch.stack([torch.logspace(-0.6, 3, 200), torch.logspace(-1.5, 3, 200), torch.logspace(-2., 3, 200)]),
                  torch.stack([torch.logspace(-0.6, 3, 200), torch.logspace(-1.4, 3, 200), torch.logspace(-1.9, 3, 200)])])

Sim = mhd.Simulator(kappa, kappastar, xi, lam, delta, False, 'Figure17')
Sim.simulate()
Sim.save()
# Out:
# [1/21] kappa=0.5, kappastar=0.2, lam=0.5, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00311639   q=55.74347058   MSE=6.23278195
# [2/21] kappa=0.5, kappastar=0.2, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00311818   q=55.71549095   MSE=6.23636058
# [3/21] kappa=0.5, kappastar=0.2, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00311840   q=55.71199998   MSE=6.23680962
# [4/21] kappa=0.5, kappastar=0.3, lam=0.5, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223603   q=56.79496606   MSE=4.47205576
# [5/21] kappa=0.5, kappastar=0.3, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223707   q=56.77147486   MSE=4.47414600
# [6/21] kappa=0.5, kappastar=0.3, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223720   q=56.76853021   MSE=4.47440656
# [7/21] kappa=0.5, kappastar=0.5, lam=0.5, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00153660   q=57.82985771   MSE=3.07320661
# [8/21] kappa=0.5, kappastar=0.5, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00153716   q=57.81041505   MSE=3.07432369
# [9/21] kappa=0.5, kappastar=0.5, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00153723   q=57.80798862   MSE=3.07446387
# [10/21] kappa=0.7, kappastar=0.3, lam=0.5, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223603   q=56.79496606   MSE=4.47205576
# [11/21] kappa=0.7, kappastar=0.3, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223707   q=56.77147291   MSE=4.47414617
# [12/21] kappa=0.7, kappastar=0.3, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00223720   q=56.76853021   MSE=4.47440656
# [13/21] kappa=0.7, kappastar=0.5, lam=0.5, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00153660   q=57.82985771   MSE=3.07320661
# [14/21] kappa=0.7, kappastar=0.5, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00153716   q=57.81041505   MSE=3.07432369
# [15/21] kappa=0.7, kappastar=0.5, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00153723   q=57.80798862   MSE=3.07446387
# [16/21] kappa=0.7, kappastar=0.6, lam=0.5, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00136277   q=58.12991683   MSE=2.72554070
# [17/21] kappa=0.7, kappastar=0.6, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00136323   q=58.11159684   MSE=2.72645100
# [18/21] kappa=0.7, kappastar=0.6, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00136328   q=58.10931151   MSE=2.72656518
# [19/21] kappa=0.7, kappastar=0.7, lam=0.5, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00123892   q=58.35807885   MSE=2.47783028
# [20/21] kappa=0.7, kappastar=0.7, lam=0.1, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00123930   q=58.34059651   MSE=2.47860276
# [21/21] kappa=0.7, kappastar=0.7, lam=0.05, Delta=0.0
# [step 0199] xi=1000.00000000   alpha=0.00123935   q=58.33841825   MSE=2.47869954
# Saving Simulator...
# ID = Figure17

# %% [markdown]
# ### **Figure 18**

# %%
kappa = np.array([0.5, 0.5, 0.5, 0.7, 0.7, 0.7, 0.7])
kappastar = np.array([0.2, 0.3, 0.5, 0.3, 0.5, 0.6, 0.7])
lam = np.array([0.5, 0.1, 0.05])
delta = 0.5

xi = torch.stack([torch.stack([torch.logspace(-0.5, 3, 200), torch.logspace(-0.5, 3, 200), torch.logspace(-0.5, 3, 200)]), 
                  torch.stack([torch.logspace(-0.4, 3, 200), torch.logspace(-0.5, 3, 200), torch.logspace(-0.5, 3, 200)]),
                  torch.stack([torch.logspace(-0.3, 3, 200), torch.logspace(-0.5, 3, 200), torch.logspace(-0.5, 3, 200)]),
                  torch.stack([torch.logspace(-0.4, 3, 200), torch.logspace(-0.5, 3, 200), torch.logspace(-0.5, 3, 200)]),
                  torch.stack([torch.logspace(-0.3, 3, 200), torch.logspace(-0.5, 3, 200), torch.logspace(-0.5, 3, 200)]),
                  torch.stack([torch.logspace(-0.3, 3, 200), torch.logspace(-0.5, 3, 200), torch.logspace(-0.5, 3, 200)]),
                  torch.stack([torch.logspace(-0.3, 3, 200), torch.logspace(-0.4, 3, 200), torch.logspace(-0.4, 3, 200)])])

Sim = mhd.Simulator(kappa, kappastar, xi, lam, delta, False, 'Figure18')
Sim.simulate()
Sim.save()
# Out:
# [1/21] kappa=0.5, kappastar=0.2, lam=0.5, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00325143   q=55.59007299   MSE=6.25285047
# [2/21] kappa=0.5, kappastar=0.2, lam=0.1, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00325336   q=55.56143271   MSE=6.25671261
# [3/21] kappa=0.5, kappastar=0.2, lam=0.05, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00325360   q=55.55785757   MSE=6.25719841
# [4/21] kappa=0.5, kappastar=0.3, lam=0.5, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00236940   q=56.61265618   MSE=4.48880651
# [5/21] kappa=0.5, kappastar=0.3, lam=0.1, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00237056   q=56.58840984   MSE=4.49112700
# [6/21] kappa=0.5, kappastar=0.3, lam=0.05, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00237071   q=56.58538376   MSE=4.49141856
# [7/21] kappa=0.5, kappastar=0.5, lam=0.5, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00166831   q=57.60791427   MSE=3.08661804
# [8/21] kappa=0.5, kappastar=0.5, lam=0.1, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00166896   q=57.58765385   MSE=3.08791809
# [9/21] kappa=0.5, kappastar=0.5, lam=0.05, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00166904   q=57.58512363   MSE=3.08808110
# [10/21] kappa=0.7, kappastar=0.3, lam=0.5, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00236940   q=56.61265618   MSE=4.48880651
# [11/21] kappa=0.7, kappastar=0.3, lam=0.1, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00237056   q=56.58840984   MSE=4.49112700
# [12/21] kappa=0.7, kappastar=0.3, lam=0.05, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00237071   q=56.58538376   MSE=4.49141856
# [13/21] kappa=0.7, kappastar=0.5, lam=0.5, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00166831   q=57.60791427   MSE=3.08661804
# [14/21] kappa=0.7, kappastar=0.5, lam=0.1, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00166896   q=57.58765385   MSE=3.08791809
# [15/21] kappa=0.7, kappastar=0.5, lam=0.05, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00166904   q=57.58512363   MSE=3.08808110
# [16/21] kappa=0.7, kappastar=0.6, lam=0.5, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00149399   q=57.89354463   MSE=2.73798357
# [17/21] kappa=0.7, kappastar=0.6, lam=0.1, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00149453   q=57.87436467   MSE=2.73906308
# [18/21] kappa=0.7, kappastar=0.6, lam=0.05, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00149460   q=57.87197016   MSE=2.73919839
# [19/21] kappa=0.7, kappastar=0.7, lam=0.5, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00136977   q=58.10958891   MSE=2.48954025
# [20/21] kappa=0.7, kappastar=0.7, lam=0.1, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00137024   q=58.09121614   MSE=2.49047003
# [21/21] kappa=0.7, kappastar=0.7, lam=0.05, Delta=0.5
# [step 0199] xi=1000.00000000   alpha=0.00137029   q=58.08892243   MSE=2.49058674
# Saving Simulator...
# ID = Figure18

# %% [markdown]
# ### **Figure 19**

# %%
kappa = [0.7, 0.5, 0.4, 0.35]
kappastar = 0.3
lam = [0.1, 0.05, 0.025, 0.005, 0.002]
delta = 1.0

Nxi = 200

noisy = [False, True, True, True, True]

xi = torch.logspace(-0.2, 3, 200)

Sim = mhd.Simulator(kappa, kappastar, xi, lam, delta, noisy, 'Figure19')
Sim.simulate()
Sim.save()
# Out:
# [1/20] kappa=0.7, kappastar=0.3, lam=0.1, Delta=1.0
# [step 0199] xi=1000.00000000   alpha=0.00250443   q=56.41073075   MSE=4.50885899
# [2/20] kappa=0.7, kappastar=0.3, lam=0.05, Delta=1.0
# [step 0050] xi=9.67407179   alpha=0.14833436   q=2.67098524   MSE=2.36999448
# [step 0060] xi=1000.00009593   alpha=0.00250459   q=56.40760427   MSE=4.50918262
# [3/20] kappa=0.7, kappastar=0.3, lam=0.025, Delta=1.0
# [step 0060] xi=9.58989566   alpha=0.14960774   q=2.61395158   MSE=2.36944515
# [step 0060] xi=1000.00009593   alpha=0.00250467   q=56.40604670   MSE=4.50934385
# [4/20] kappa=0.7, kappastar=0.3, lam=0.005, Delta=1.0
# [step 0087] xi=9.61216325   alpha=0.14983146   q=2.58986836   MSE=2.38040892
# [step 0060] xi=1000.00009593   alpha=0.00250474   q=56.40480079   MSE=4.50947289
# [5/20] kappa=0.7, kappastar=0.3, lam=0.002, Delta=1.0
# [step 0092] xi=9.67874127   alpha=0.14926219   q=2.60276279   MSE=2.38934025
# [step 0060] xi=1000.00009593   alpha=0.00250475   q=56.40461392   MSE=4.50949225
# [6/20] kappa=0.5, kappastar=0.3, lam=0.1, Delta=1.0
# [step 0199] xi=1000.00000000   alpha=0.00250443   q=56.41073075   MSE=4.50885899
# [7/20] kappa=0.5, kappastar=0.3, lam=0.05, Delta=1.0
# [step 0050] xi=9.66475969   alpha=0.14842049   q=2.66862928   MSE=2.36889680
# [step 0060] xi=1000.00009593   alpha=0.00250459   q=56.40760427   MSE=4.50918262
# [8/20] kappa=0.5, kappastar=0.3, lam=0.025, Delta=1.0
# [step 0064] xi=9.71381903   alpha=0.14844043   q=2.64589114   MSE=2.38384690
# [step 0060] xi=1000.00009593   alpha=0.00250467   q=56.40604670   MSE=4.50934385
# [9/20] kappa=0.5, kappastar=0.3, lam=0.005, Delta=1.0
# [step 0075] xi=9.65179384   alpha=0.14945148   q=2.60025885   MSE=2.38494967
# [step 0060] xi=1000.00009593   alpha=0.00250474   q=56.40480079   MSE=4.50947289
# [10/20] kappa=0.5, kappastar=0.3, lam=0.002, Delta=1.0
# [step 0088] xi=9.89536916   alpha=0.14723273   q=2.65916831   MSE=2.41384440
# [step 0060] xi=1000.00009593   alpha=0.00250475   q=56.40461392   MSE=4.50949225
# [11/20] kappa=0.4, kappastar=0.3, lam=0.1, Delta=1.0
# [step 0199] xi=1000.00000000   alpha=0.00250443   q=56.41073075   MSE=4.50885899
# [12/20] kappa=0.4, kappastar=0.3, lam=0.05, Delta=1.0
# [step 0054] xi=9.75339768   alpha=0.14760564   q=2.69100930   MSE=2.37931307
# [step 0060] xi=1000.00009593   alpha=0.00250459   q=56.40760426   MSE=4.50918262
# [13/20] kappa=0.4, kappastar=0.3, lam=0.025, Delta=1.0
# [step 0063] xi=9.76648209   alpha=0.14795133   q=2.65939743   MSE=2.38992812
# [step 0060] xi=1000.00009593   alpha=0.00250467   q=56.40604670   MSE=4.50934385
# [14/20] kappa=0.4, kappastar=0.3, lam=0.005, Delta=1.0
# [step 0080] xi=9.74213525   alpha=0.14859453   q=2.62385124   MSE=2.39525611
# [step 0060] xi=1000.00009593   alpha=0.00250474   q=56.40480079   MSE=4.50947289
# [15/20] kappa=0.4, kappastar=0.3, lam=0.002, Delta=1.0
# [step 0111] xi=9.71967692   alpha=0.14887314   q=2.61347831   MSE=2.393997692
# [step 0060] xi=1000.00009593   alpha=0.00250475   q=56.40461392   MSE=4.50949225
# [16/20] kappa=0.35, kappastar=0.3, lam=0.1, Delta=1.0
# [step 0199] xi=1000.00000000   alpha=0.00250443   q=56.41073075   MSE=4.50885899
# [17/20] kappa=0.35, kappastar=0.3, lam=0.05, Delta=1.0
# [step 0054] xi=9.64612423   alpha=0.14859324   q=2.66391112   MSE=2.36669772
# [step 0060] xi=1000.00009593   alpha=0.00250459   q=56.40760427   MSE=4.50918262
# [18/20] kappa=0.35, kappastar=0.3, lam=0.025, Delta=1.0
# [step 0069] xi=9.89218012   alpha=0.14680026   q=2.69147737   MSE=2.40434916
# [step 0060] xi=1000.00009593   alpha=0.00250467   q=56.40604670   MSE=4.50934385
# [19/20] kappa=0.35, kappastar=0.3, lam=0.005, Delta=1.0
# [step 0091] xi=9.59581072   alpha=0.14998899   q=2.58557359   MSE=2.378531832
# [step 0060] xi=1000.00009593   alpha=0.00250474   q=56.40480079   MSE=4.50947289
# [20/20] kappa=0.35, kappastar=0.3, lam=0.002, Delta=1.0
# [step 0099] xi=9.67229036   alpha=0.14932374   q=2.60107170   MSE=2.388605162
# [step 0060] xi=1000.00009593   alpha=0.00250475   q=56.40461392   MSE=4.50949225
# Saving Simulator...
# ID = Figure19
